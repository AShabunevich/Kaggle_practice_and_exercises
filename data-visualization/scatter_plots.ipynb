# %% [markdown]
# Load libraries and data.

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

candy_filepath = '~/Desktop/Kaggle/practice/Data_Visualization/candy.csv'
candy_data = pd.read_csv(candy_filepath, index_col="id")

candy_data.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %% [markdown]
# ## The role of sugar
#
# Do people tend to prefer candies with higher sugar content?
#
# #### Part A
#
# Create a scatter plot that shows the relationship between `'sugarpercent'` (on the horizontal x-axis) and `'winpercent'` (on the vertical y-axis).  _Don't add a regression line just yet -- you'll do that in the next step!_

# %%
#scatter plot
sns.scatterplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %% [markdown]
# #### Part B
#
# Does the scatter plot show a **strong** correlation between the two variables?  If so, are candies with more sugar relatively more or less popular with the survey respondents?
#
# - There is no strong correlation between the two variables. Thus, sugar content does not play a strong role in candy popularity.

# %% [markdown]
# ## Take a closer look
#
# #### Part A
#
# Create the same scatter plot you created in **Step 3**, but now with a regression line!

# %%
#scattered plot with regresion line
sns.regplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %% [markdown]
# #### Part B
#
# According to the plot above, is there a **slight** correlation between `'winpercent'` and `'sugarpercent'`?  What does this tell you about the candy that people tend to prefer?
#
# - There is slightly positive slope, so there is slightly positive correlation between `'winpercent'` and `'sugarpercent'`. Thus, people have a slight preference for candies that have higher percent of sugar.

# %% [markdown]
# ## Chocolate!
#
# In the code cell below, create a scatter plot to show the relationship between `'pricepercent'` (on the horizontal x-axis) and `'winpercent'` (on the vertical y-axis). Use the `'chocolate'` column to color-code the points.  _Don't add any regression lines just yet -- you'll do that in the next step!_

# %%
#scatered plot with 3 variables
sns.scatterplot(x=candy_data['pricepercent'], y=candy_data['winpercent'], hue=candy_data['chocolate'])
# Out:
# <AxesSubplot:xlabel='pricepercent', ylabel='winpercent'>

# %% [markdown]
# ## Investigate chocolate
#
# #### Part A
#
# Create the same scatter plot you created in **Chocolate!**, but now with two regression lines, corresponding to (1) chocolate candies and (2) candies without chocolate.

# %%
#scatter plot with 3 variables and regression line
sns.lmplot(x="pricepercent", y="winpercent", hue="chocolate", data=candy_data)

# %% [markdown]
# #### Part B
#
# Using the regression lines, what conclusions can you draw about the effects of chocolate and price on candy popularity?
#
# - Chocolate candies have slightly positive slope. Thus, more expencive chocolate candies tend to be more popular.
# - Not chocolate candies have slightly negative slope. Thus, more expensive non-chocolate candies tend to be less popular.

# %% [markdown]
# ## Everybody loves chocolate.
#
# #### Part A
#
# Create a categorical scatter plot to highlight the relationship between `'chocolate'` and `'winpercent'`.  Put `'chocolate'` on the (horizontal) x-axis, and `'winpercent'` on the (vertical) y-axis.

# %%
#categorical scatter plot
sns.swarmplot(x=candy_data['chocolate'], y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='winpercent'>

# %% [markdown]
# #### Part B
#
# You decide to dedicate a section of your report to the fact that chocolate candies tend to be more popular than candies without chocolate.  Which plot is more appropriate to tell this story: the plot from **Ivestigate chocolate**, or the plot from this section?
#
# - This plot (categorical scatter plot) is the most appropriate plot. The plot from previous section contains more information that could distract from main point.
